# %% [markdown]
# # Peшетка пробел текст

# %%
from game_v2 import score_game #Так правильно делать импорт функции
from game_v2 import random_predict
score_game(random_predict) #вызов функции

#Но можно и так:
from game_v2 import score_game, random_predict #И это тоже правильно
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 from game_v2 import score_game #Так правильно делать импорт функции
#       2 from game_v2 import random_predict
#       3 score_game(random_predict) #вызов функции
#
# ModuleNotFoundError: No module named 'game_v2'

# %% [markdown]
# ### Важно! Хорошим тоном считается переносить код в файлы Python, чтобы с ним было проще работать на продакшене, а в Jupyter Notebook делать исключительно презентацию.

# %% [markdown]
# ## Ещё одна особенность Jupyter Notebook в VS Code — возможность просмотра переменных. При изменении переменных мы также сможем увидеть результат этих изменений.

# %%
n=123

# %%
z=n

# %%
n=1
print(z)
# Out:
# 123
