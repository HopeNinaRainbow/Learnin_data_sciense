# %%
igroki1 = "Александр Михаил Максим"
igroki2 = "\nСеогей\nАндрей\nЛеонид"
print('Первый тур:', igroki1)
print('Второй тур:', igroki2)
print("""Сегодня будет жарко""")
# Out:
# Первый тур: Александр Михаил Максим
# Второй тур:
# Сеогей
# Андрей
# Леонид
# Сегодня будет жарко

# %%
# Для решения задач нам понадобится выделить из признака title год выпуска фильма. Для этого напишем функцию get_year_release(arg).м

import re #библиотека для регулярных выражений
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None
