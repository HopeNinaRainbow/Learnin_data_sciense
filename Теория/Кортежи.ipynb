# %% [markdown]
# #### Кортежи занимают меньший объём памяти.
# #### Чтобы увидеть это, можно воспользоваться хитрым методом у структур данных
# #### — .__sizeof__()

# %% [markdown]
# #### На практике кортеж используется редко.
# #### Иногда возникает потребность создать кортеж из нескольких переменных, например номеров складов, по которым идёт расчёт каких-то статистик.
# #### И хочется, чтобы эти номера нельзя было неявно перезаписать. Тогда кортеж — ваш выбор.

# %%
tpl3 = ("s") # Строка
tpl4 = ("s", ) # Кортеж
